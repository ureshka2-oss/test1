# %% [markdown]
# # Global Energy Market Analysis
# ## Market Sizing & Competitive Benchmarking
#
# Analysis of 20 energy companies across 6 regions and 5 sectors.

# %%
import sys
sys.path.insert(0, '..')

import pandas as pd
import matplotlib.pyplot as plt
from src.data_loader import load_market_data, clean_data
from src.analysis import market_size_by_sector, regional_benchmark, growth_leaders, sustainability_score

df = load_market_data()
df_clean = clean_data(df)
print(f"Loaded {len(df)} companies")
df.head()

# %% [markdown]
# ## 1. Market Size by Sector

# %%
sector_analysis = market_size_by_sector(df)
sector_analysis

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

sector_analysis['total_revenue_2023'].plot(kind='bar', ax=axes[0], color='#2563eb')
axes[0].set_title('Total Revenue by Sector (2023, $Bn)')
axes[0].set_ylabel('Revenue ($Bn)')

sector_analysis['total_market_cap'].plot(kind='bar', ax=axes[1], color='#16a34a')
axes[1].set_title('Total Market Cap by Sector ($Bn)')
axes[1].set_ylabel('Market Cap ($Bn)')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Growth Leaders

# %%
leaders = growth_leaders(df, top_n=10)
leaders

# %% [markdown]
# ## 3. Sustainability Scorecard

# %%
scores = sustainability_score(df)
scores

# %% [markdown]
# ## 4. Regional Benchmark

# %%
benchmark = regional_benchmark(df)
benchmark
